# %%
# ----- Lab 1 starts here (Web Scraping Single Page)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
pd.set_option('display.max_rows', 20)

# %%
url = "https://www.billboard.com/charts/hot-100/"

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
#Title
titles = []
for title in soup.select("#title-of-a-story")[3:103]:
    titles.append(title.get_text().strip())
    
# Artist
artists = []
for artist in soup.select("li.o-chart-results-list__item.\/\/.lrv-u-flex-grow-1.lrv-u-flex.lrv-u-flex-direction-column.lrv-u-justify-content-center.lrv-u-border-b-1.u-border-b-0\@mobile-max.lrv-u-border-color-grey-light.lrv-u-padding-l-1\@mobile-max > span"):
    artists.append(artist.get_text().strip())
    
top100billboard = pd.DataFrame({'artist':artists,'title':titles})

# %%
top100billboard.head(60)
# Out:
#                                                artist  \
# 0                                        Taylor Swift
# 1                                               Adele
# 2                       The Kid LAROI & Justin Bieber
# 3                             Lil Nas X & Jack Harlow
# 4            Silk Sonic (Bruno Mars & Anderson .Paak)
# 5                                          Ed Sheeran
# 6                                          Ed Sheeran
# 7                                       Glass Animals
# 8                                            Doja Cat
# 9                                        Walker Hayes
# 10                              Elton John & Dua Lipa
# 11                Drake Featuring Future & Young Thug
# 12                                     Olivia Rodrigo
# 13                              Doja Cat & The Weeknd
# 14              Wizkid Featuring Justin Bieber & Tems
# 15                                           Maneskin
# 16                                           Dua Lipa
# 17                                       Taylor Swift
# 18                           Post Malone & The Weeknd
# 19                                         Juice WRLD
# 20                             Doja Cat Featuring SZA
# 21             Taylor Swift Featuring Chris Stapleton
# 22           Silk Sonic (Bruno Mars & Anderson .Paak)
# 23                    Jason Aldean & Carrie Underwood
# 24                                       Taylor Swift
# 25                         The Weeknd & Ariana Grande
# 26            Drake Featuring 21 Savage & Project Pat
# 27                   THE ANXIETY: WILLOW & Tyler Cole
# 28                       NEIKED X Mae Muller X Polo G
# 29  Dustin Lynch Featuring Lauren Alaina Or MacKen...
# 30                           Drake Featuring Lil Baby
# 31                                         Luke Combs
# 32                                      Justin Bieber
# 33                                               CKay
# 34                        Ryan Hurd With Maren Morris
# 35                                       Mariah Carey
# 36                                     Coldplay x BTS
# 37                  Jordan Davis Featuring Luke Bryan
# 38                                          Lil Nas X
# 39                                      Billie Eilish
# 40                                            Farruko
# 41                                    Chris Stapleton
# 42             Taylor Swift Featuring Phoebe Bridgers
# 43  Nardo Wick Featuring G Herbo, Lil Durk & 21 Sa...
# 44                                       Taylor Swift
# 45                                       Taylor Swift
# 46                  Taylor Swift Featuring Ed Sheeran
# 47                                          Lil Nas X
# 48                                             Polo G
# 49                                     Zac Brown Band
# 50                                       Taylor Swift
# 51                                       Taylor Swift
# 52                                         Luke Combs
# 53                                       Taylor Swift
# 54                                       Taylor Swift
# 55                                Summer Walker & SZA
# 56                          Normani Featuring Cardi B
# 57                                              Chloe
# 58                                       Taylor Swift
# 59               Blxst & Tyga Featuring Ty Dolla $ign
#
#                                                 title
# 0                     All Too Well (Taylor's Version)
# 1                                          Easy On Me
# 2                                                Stay
# 3                                       Industry Baby
# 4                               Smokin Out The Window
# 5                                          Bad Habits
# 6                                             Shivers
# 7                                          Heat Waves
# 8                                        Need To Know
# 9                                          Fancy Like
# 10                            Cold Heart (PNAU Remix)
# 11                                         Way 2 Sexy
# 12                                           Good 4 U
# 13                                          You Right
# 14                                            Essence
# 15                                            Beggin'
# 16                                         Levitating
# 17                  State Of Grace (Taylor's Version)
# 18                                      One Right Now
# 19                                       Already Dead
# 20                                       Kiss Me More
# 21  I Bet You Think About Me (Taylor's Version) (F...
# 22                                Leave The Door Open
# 23                               If I Didn't Love You
# 24                             Red (Taylor's Version)
# 25                                    Save Your Tears
# 26                                         Knife Talk
# 27                                Meet Me At Our Spot
# 28                                        Better Days
# 29                                 Thinking 'Bout You
# 30                                   Girls Want Girls
# 31                                        Cold As You
# 32                                              Ghost
# 33                           Love Nwantiti (Ah Ah Ah)
# 34                                  Chasing After You
# 35                    All I Want For Christmas Is You
# 36                                        My Universe
# 37                                           Buy Dirt
# 38                                  Thats What I Want
# 39                                  Happier Than Ever
# 40                                              Pepas
# 41                          You Should Probably Leave
# 42    Nothing New (Taylor's Version) (From The Vault)
# 43                                   Who Want Smoke??
# 44  Message In A Bottle (Taylor's Version) (From T...
# 45         I Knew You Were Trouble (Taylor's Version)
# 46            Run (Taylor's Version) (From The Vault)
# 47                     Montero (Call Me By Your Name)
# 48                          Bad Man (Smooth Criminal)
# 49                                          Same Boat
# 50     Better Man (Taylor's Version) (From The Vault)
# 51                              22 (Taylor's Version)
# 52                                         Doin' This
# 53                     Treacherous (Taylor's Version)
# 54  We Are Never Ever Getting Back Together (Taylo...
# 55                                            No Love
# 56                                          Wild Side
# 57                                         Have Mercy
# 58                     I Almost Do (Taylor's Version)
# 59                                             Chosen

# %%
# ----- Lab 2 starts here (Web Scraping Multiple Pages)

# %%
# PopVortex iTunes Top100 USA

# %%
url = 'http://www.popvortex.com/music/charts/top-100-songs.php'

# %%
response = requests.get(url)
display(url,response.status_code)
# Out:
# 'http://www.popvortex.com/music/charts/top-100-songs.php'
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
#Title
titles = []
for title in soup.select("cite.title"):
    titles.append(title.get_text())
    
# Artist
artists = []
for artist in soup.select("em.artist"):
    artists.append(artist.get_text())
    
top100vortex = pd.DataFrame({'artist':artists,'title':titles})
top100vortex.head(60)
# Out:
#                                      artist  \
# 0                                     Adele
# 1               State of Mine & Drew Jacobs
# 2                     Elton John & Dua Lipa
# 3                                     GAYLE
# 4                              Walker Hayes
# 5                                Ed Sheeran
# 6                              Walker Hayes
# 7                                  Kid Rock
# 8                                 Emmy Meli
# 9                                  Måneskin
# 10                           Girl Named Tom
# 11                             Jessie Murph
# 12          Jason Aldean & Carrie Underwood
# 13                 Post Malone & The Weeknd
# 14                             Jordan Davis
# 15  Bruno Mars, Anderson .Paak & Silk Sonic
# 16         THE ANXIETY, WILLOW & Tyler Cole
# 17                               Brenda Lee
# 18                           Jennifer Lopez
# 19                 Shane Smith & the Saints
# 20                               Luke Combs
# 21                             Mariah Carey
# 22                           Girl Named Tom
# 23                                    Adele
# 24                 Trans-Siberian Orchestra
# 25                             Jason Aldean
# 26                                    Adele
# 27                             Walker Hayes
# 28                     Jimmie Allen & Nelly
# 29                          Chris Stapleton
# 30                  Lil Nas X & Jack Harlow
# 31                                    Adele
# 32                             Cody Johnson
# 33                            Glass Animals
# 34                                    Adele
# 35                           Coldplay X BTS
# 36                            Morgan Wallen
# 37                               Ed Sheeran
# 38                            Blake Shelton
# 39                            Justin Bieber
# 40                             Taylor Swift
# 41                         Carrie Underwood
# 42                                    Latto
# 43                                    Adele
# 44                                   Acraze
# 45                                   Hwa Sa
# 46                        The Band McMillan
# 47                          Chris Stapleton
# 48            Carly Pearce & Ashley McBryde
# 49                            Justin Bieber
# 50                               The Weeknd
# 51                 Ryan Hurd & Maren Morris
# 52                                    Adele
# 53                           Casting Crowns
# 54              Elle King & Miranda Lambert
# 55                                      BTS
# 56                           Olivia Rodrigo
# 57              Jimmie Allen & Brad Paisley
# 58                               Kane Brown
# 59                              Tyson James
#
#                                               title
# 0                                        Easy On Me
# 1                                     God's Country
# 2                           Cold Heart (PNAU Remix)
# 3                                           abcdefu
# 4                                        Fancy Like
# 5                                           Shivers
# 6                                                AA
# 7   Don't Tell Me How To Live (feat. Monster Truck)
# 8                                        I AM WOMAN
# 9                                            Beggin
# 10                            More Hearts Than Mine
# 11                                  Always Been You
# 12                             If I Didn't Love You
# 13                                    One Right Now
# 14                      Buy Dirt (feat. Luke Bryan)
# 15                            Smokin Out The Window
# 16                       Meet Me At Our Spot (Live)
# 17       Rockin' Around the Christmas Tree (Single)
# 18                             On My Way (Marry Me)
# 19                                 All I See Is You
# 20                                       Doin' This
# 21                  All I Want For Christmas Is You
# 22         Dust In The Wind (The Voice Performance)
# 23                                     I Drink Wine
# 24        Christmas / Sarajevo 12/24 (Instrumental)
# 25                                           Heaven
# 26                                      To Be Loved
# 27                                           U Gurl
# 28                                  Good Times Roll
# 29                        You Should Probably Leave
# 30                                    INDUSTRY BABY
# 31                                        Oh My God
# 32                                   'Til You Can't
# 33                                       Heat Waves
# 34                                          Hold On
# 35                                      My Universe
# 36                                 Sand In My Boots
# 37                                       Bad Habits
# 38                       Come Back As A Country Boy
# 39                                            Ghost
# 40                                        Enchanted
# 41                                   Stretchy Pants
# 42                                       Big Energy
# 43                                            Hello
# 44                      Do It To It (feat. Cherish)
# 45                                             FOMO
# 46                                Somebody's Got To
# 47                                Tennessee Whiskey
# 48                     Never Wanted To Be That Girl
# 49                                        Mistletoe
# 50                                  Blinding Lights
# 51                                Chasing After You
# 52                              Rolling in the Deep
# 53                                  Scars in Heaven
# 54                Drunk (And I Don't Wanna Go Home)
# 55                                           Butter
# 56                                          traitor
# 57                            Freedom Was A Highway
# 58                                  One Mississippi
# 59                                      Rittenhouse

# %%
# Apple Music Top100 Global

# %%
url = 'https://music.apple.com/us/playlist/top-100-global/pl.d25f5d1181894928af76c85c967f8f31'

# %%
response = requests.get(url)
display(url,response.status_code)
# Out:
# 'https://music.apple.com/us/playlist/top-100-global/pl.d25f5d1181894928af76c85c967f8f31'
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
#Artist
soup.select("div.songs-list-row__by-line")[0].get_text().strip()
# Out:
# 'Adele'

# %%
#Title
soup.select("div.songs-list-row__song-wrapper > div > div.songs-list-row__song-name")[0].get_text()
# Out:
# 'Easy On Me'

# %%
#Title
titles = []
for title in soup.select("div.songs-list__col.songs-list__col--song.typography-body > div > div.songs-list-row__song-wrapper > div"):
    titles.append(title.get_text().strip())
    
# Artist
artists = []
for artist in soup.select("div.songs-list-row__by-line"):
    artists.append(artist.get_text().strip())
    
top100apple = pd.DataFrame({'artist':artists,'title':titles})
top100apple['title'] = top100apple['title'].apply(lambda x: x.split("\n")[0])
top100apple.head(60)
# Out:
#                                         artist  \
# 0                                        Adele
# 1                                        Adele
# 2                                        Adele
# 3                                        Adele
# 4               The Kid LAROI &  Justin Bieber
# 5                                        Adele
# 6                                        Adele
# 7                                        Adele
# 8                                        Adele
# 9                                        Drake
# 10                                Taylor Swift
# 11  Bruno Mars,  Anderson .Paak, &  Silk Sonic
# 12                                       Adele
# 13                                       Adele
# 14                                       Adele
# 15                                  Ed Sheeran
# 16                                       Drake
# 17                    Lil Nas X &  Jack Harlow
# 18                        Summer Walker &  SZA
# 19                                       Adele
# 20                                  Ed Sheeran
# 21                               Glass Animals
# 22                                Mariah Carey
# 23                                  Nardo Wick
# 24                                       Drake
# 25                                    Doja Cat
# 26                                       GAYLE
# 27                                       Yuuri
# 28                                    Rod Wave
# 29                      Elton John &  Dua Lipa
# 30                       Amaarae &  Kali Uchis
# 31                            Macaroni Empitsu
# 32                   Post Malone &  The Weeknd
# 33                                 Kodak Black
# 34                                       Drake
# 35              NEIKED,  Mae Muller, &  Polo G
# 36                               Billie Eilish
# 37  Bruno Mars,  Anderson .Paak, &  Silk Sonic
# 38                                 back number
# 39                                     Farruko
# 40                    Summer Walker &  Cardi B
# 41                                    Doja Cat
# 42                                  Juice WRLD
# 43                               Summer Walker
# 44                                      Polo G
# 45                                       Yuuri
# 46                                  Young Thug
# 47                                Taylor Swift
# 48                               Summer Walker
# 49                                   Meek Mill
# 50                               Summer Walker
# 51                               Summer Walker
# 52                                  The Weeknd
# 53                                         BTS
# 54                                Taylor Swift
# 55           Summer Walker,  JT, &  City Girls
# 56                                       Drake
# 57                                 Young Dolph
# 58                                       Drake
# 59                                       Drake
#
#                                                 title
# 0                                          Easy On Me
# 1                                           Oh My God
# 2                                      My Little Love
# 3                                        I Drink Wine
# 4                                                STAY
# 5                                        Can I Get It
# 6                                  Cry Your Heart Out
# 7                                 Strangers By Nature
# 8                                         To Be Loved
# 9          Knife Talk (feat. 21 Savage & Project Pat)
# 10  All Too Well (10 Minute Version) (Taylor's Ver...
# 11                              Smokin Out The Window
# 12                                            Hold On
# 13                                      Woman Like Me
# 14   All Night Parking (with Erroll Garner) Interlude
# 15                                            Shivers
# 16             Way 2 Sexy (feat. Future & Young Thug)
# 17                                      INDUSTRY BABY
# 18                                            No Love
# 19                                     Love Is A Game
# 20                                         Bad Habits
# 21                                         Heat Waves
# 22                    All I Want For Christmas Is You
# 23  Who Want Smoke?? (feat. G Herbo, Lil Durk & 21...
# 24                  Girls Want Girls (feat. Lil Baby)
# 25                                       Need To Know
# 26                                            abcdefu
# 27                                         BETELGEUSE
# 28                                       By Your Side
# 29                            Cold Heart (PNAU Remix)
# 30            Sad Girlz Luv Money Remix (feat. Moliy)
# 31                                     Nanndemonaiyo,
# 32                                      One Right Now
# 33                                      Super Gremlin
# 34                    Fair Trade (feat. Travis Scott)
# 35                                        Better Days
# 36                                  Happier Than Ever
# 37                                Leave The Door Open
# 38                                          Suiheisen
# 39                                              Pepas
# 40                      Bitter (Narration By Cardi B)
# 41                           Kiss Me More (feat. SZA)
# 42                                       Already Dead
# 43                                             Insane
# 44                          Bad Man (Smooth Criminal)
# 45                                       Dried Flower
# 46                 Bubbly (with Drake & Travis Scott)
# 47                                          Enchanted
# 48                                      Throw It Away
# 49      Sharing Locations (feat. Lil Baby & Lil Durk)
# 50                                        Reciprocate
# 51                             Toxic (feat. Lil Durk)
# 52                                    Blinding Lights
# 53                                             Butter
# 54                    All Too Well (Taylor's Version)
# 55                                    Ex For A Reason
# 56                         No Friends In The Industry
# 57                                          100 Shots
# 58                   Wants and Needs (feat. Lil Baby)
# 59             In The Bible (feat. Lil Durk & GIVĒON)

# %%
# 4 Decades between 1980 - 2010
# TSORT Top100 by decade

# %%
url2010 = 'http://tsort.info/music/ds2010.htm'
url2000 = 'http://tsort.info/music/ds2000.htm'
url1990 = 'http://tsort.info/music/ds1990.htm'
url1980 = 'http://tsort.info/music/ds1980.htm'

# %%
for url in [url2010, url2000,url1990,url1980]:
    response = requests.get(url)
    display(url,response.status_code)
# Out:
# 'http://tsort.info/music/ds2010.htm'
# 200
# 'http://tsort.info/music/ds2000.htm'
# 200
# 'http://tsort.info/music/ds1990.htm'
# 200
# 'http://tsort.info/music/ds1980.htm'
# 200

# %%
soup2010 = BeautifulSoup(requests.get(url2010).content, "html.parser")
soup2000 = BeautifulSoup(requests.get(url2000).content, "html.parser")
soup1990 = BeautifulSoup(requests.get(url1990).content, "html.parser")
soup1980 = BeautifulSoup(requests.get(url1980).content, "html.parser")

# %%
#1980
artists = []
titles = []
years = []

for artist in soup1980.select("td.art"): #Artist
    artists.append(artist.get_text())
    
for title in soup1980.select("td.tit"): #Title
    titles.append(title.get_text())
    
for year in soup1980.select("td.yer"): #Year
    years.append(year.get_text())

year1980 = pd.DataFrame({'artist':artists, 'title':titles, 'year':years})

# %%
#1990
artists = []
titles = []
years = []

for artist in soup1990.select("td.art"): #Artist
    artists.append(artist.get_text())
    
for title in soup1990.select("td.tit"): #Title
    titles.append(title.get_text())
    
for year in soup1990.select("td.yer"): #Year
    years.append(year.get_text())

year1990 = pd.DataFrame({'artist':artists, 'title':titles, 'year':years})

# %%
#2000
artists = []
titles = []
years = []

for artist in soup2000.select("td.art"): #Artist
    artists.append(artist.get_text())
    
for title in soup2000.select("td.tit"): #Title
    titles.append(title.get_text())
    
for year in soup2000.select("td.yer"): #Year
    years.append(year.get_text())

year2000 = pd.DataFrame({'artist':artists, 'title':titles, 'year':years})

# %%
#2010
artists = []
titles = []
years = []

for artist in soup2010.select("td.art"): #Artist
    artists.append(artist.get_text())
    
for title in soup2010.select("td.tit"): #Title
    titles.append(title.get_text())
    
for year in soup2010.select("td.yer"): #Year
    years.append(year.get_text())

year2010 = pd.DataFrame({'artist':artists, 'title':titles, 'year':years})

# %%
top100_80s_10s = pd.concat([year1980,year1990,year2000,year2010], axis = 0)

# %%
top100_80s_10s.head(60)
# Out:
#                             artist  \
# 0                       Pink Floyd
# 1                       Irene Cara
# 2                       Kim Carnes
# 3                       The Police
# 4                  Michael Jackson
# 5                    Stevie Wonder
# 6                   USA For Africa
# 7                   George Michael
# 8                         Survivor
# 9                          Madonna
# 10                Barbra Streisand
# 11     Joan Jett & The Blackhearts
# 12                    Culture Club
# 13                    Phil Collins
# 14                     John Lennon
# 15                          Prince
# 16                    Culture Club
# 17                      Diana Ross
# 18                 Whitney Houston
# 19                            A-Ha
# 20                         Blondie
# 21                     Rick Astley
# 22  Paul McCartney & Stevie Wonder
# 23                 Michael Jackson
# 24                       Starsound
# 25              Olivia Newton-John
# 26                          Berlin
# 27                The Human League
# 28                       Los Lobos
# 29                           Falco
# 30                        Band Aid
# 31                       Foreigner
# 32        Dionne Warwick & Friends
# 33                       Lipps Inc
# 34                     Tina Turner
# 35                    Cyndi Lauper
# 36                     David Bowie
# 37       Frankie Goes To Hollywood
# 38      Diana Ross & Lionel Richie
# 39                  George Michael
# 40               Steve Miller Band
# 41                         Madonna
# 42                 Tears For Fears
# 43                           Queen
# 44                              U2
# 45                     The Bangles
# 46                       Soft Cell
# 47                    J Geils Band
# 48                           Wham!
# 49               The Pet Shop Boys
# 50                    Phil Collins
# 51                    Bonnie Tyler
# 52                   Lionel Richie
# 53   Bill Medley & Jennifer Warnes
# 54                  Bobby McFerrin
# 55            Fine Young Cannibals
# 56                   Lionel Richie
# 57                         Roxette
# 58                            UB40
# 59                     The Bangles
#
#                                          title  year
# 0           Another Brick in the Wall (part 2)  1980
# 1                 Flashdance... What a Feeling  1983
# 2                             Bette Davis Eyes  1981
# 3                        Every Breath You Take  1983
# 4                                  Billie Jean  1983
# 5              I Just Called to Say I Love You  1984
# 6                             We Are the World  1985
# 7                             Careless Whisper  1984
# 8                             Eye of the Tiger  1982
# 9                                Like a Prayer  1989
# 10                             A Woman in Love  1980
# 11                        I Love Rock 'n' Roll  1982
# 12                             Karma Chameleon  1983
# 13                     Another Day in Paradise  1989
# 14                   (Just Like) Starting Over  1980
# 15                              When Doves Cry  1984
# 16              Do You Really Want to Hurt Me?  1982
# 17                                 Upside Down  1980
# 18  I Wanna Dance With Somebody (Who Loves Me)  1987
# 19                                  Take On Me  1985
# 20                                     Call Me  1980
# 21                     Never Gonna Give You Up  1987
# 22                               Ebony & Ivory  1982
# 23                                     Beat It  1983
# 24                                 Stars On 45  1981
# 25                        (Let's Get) Physical  1981
# 26                         Take My Breath Away  1986
# 27                           Don't You Want Me  1982
# 28                                    La Bamba  1987
# 29                             Rock Me Amadeus  1986
# 30                Do They Know It's Christmas?  1984
# 31                 I Want to Know What Love Is  1985
# 32                 That's What Friends Are For  1986
# 33                                   Funkytown  1980
# 34              What's Love Got to Do With It?  1984
# 35                   Girls Just Wanna Have Fun  1984
# 36                                 Let's Dance  1983
# 37                                       Relax  1984
# 38                                Endless Love  1981
# 39                                       Faith  1987
# 40                                 Abracadabra  1982
# 41                           Papa Don't Preach  1986
# 42                                       Shout  1985
# 43                  Another One Bites the Dust  1980
# 44                         With Or Without You  1987
# 45                       Walk Like an Egyptian  1986
# 46                                Tainted Love  1981
# 47                                  Centrefold  1982
# 48                 Wake Me Up Before You Go Go  1984
# 49                              West End Girls  1986
# 50                       A Groovy Kind of Love  1988
# 51                  Total Eclipse of the Heart  1983
# 52                             Say You, Say Me  1985
# 53              (I've Had) the Time of My Life  1987
# 54                        Don't Worry Be Happy  1988
# 55                         She Drives Me Crazy  1989
# 56                  All Night Long (All Night)  1983
# 57                                    The Look  1989
# 58                                Red Red Wine  1983
# 59                               Eternal Flame  1989

# %%
# ----- Lab 3 starts here (User Input & Hot Song Recommender)

# %%
# Compose hot songs dataframe (top100billboard, top100vortex, top100apple)

hot_songs = pd.concat([top100billboard,top100vortex,top100apple], axis = 0)
# Not removing duplicates on purpose... they do not spoil anything here, and actually can make the user input matched a bit more frequently

# lower case
hot_songs['artist'] = hot_songs['artist'].apply(lambda x: x.lower())
hot_songs['title'] = hot_songs['title'].apply(lambda x: x.lower())
hot_songs.sort_values(by = 'title', inplace = True)

# %%
# Read user input
song = input('Please type the song name:').lower()
artist = input('Please type the artist:').lower()
# Out:
# Please type the song name: aaa
# Please type the artist: aaa

# %%
import random

# If user typed the correct title and artist of a hot song, return any (other) hot song

if hot_songs[(hot_songs['title'] == song) & (hot_songs['artist'] == artist)].count()[0] > 0:
    rand_song = hot_songs[(hot_songs['title'] != song) & (hot_songs['artist'] != artist)].iloc[random.choice(hot_songs.index)]
    new_song = rand_song[0] + ' - ' + rand_song[1]
    print('Hot song entered, why don\'t you try this one then:')
    print('\033[1;32m', new_song)

# %%
# ----- Lab 4 starts here (API wrappers - Create your collection of songs & audio features)

# %%
# Creating Spotify wrapper

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

secrets_file = open("secrets.txt","r")
string = secrets_file.read()

secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'], client_secret=secrets_dict['csecret']))

# %%
# Playlist crawler - get song name, artists, uri and song features
# Not the cleanest or quickest code.. but it does the job

def playlist_crawler(playlist_id):

    import pandas as pd 
    from random import randint
    from time import sleep
    from tqdm import tqdm as tqdm
    import time
    
    # tracks extractor
    results = sp.user_playlist_tracks("spotify",playlist_id)

    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,2))

    data = []
    for item in tracks:
        if item['track'] is not None:
            for artist in item['track']['artists']:
                data.append([(item['track']['name'], artist['name'], item['track']['uri'])])

    data = [item for sublist in data for item in sublist] # flatten the list of lists

    # feature extractor
    features = []
    for item in data:
        features.append(sp.audio_features(item[2]))

    df_features = pd.DataFrame([])
    for song in features:
        df_features = df_features.append([song[0]])


    semi = pd.DataFrame([])
    for item in data:
        semi = semi.append(pd.Series(item), ignore_index=True)
        
    df_features = df_features.reset_index(drop=True)
    
    global final
    
    final = pd.concat([semi,df_features], axis = 1)

    final.columns.values[0] = 'title'
    final.columns.values[1] = 'artist'
    final.columns.values[2] = 'uri2'

    final = final[['title','artist','danceability','energy','key','loudness','mode','speechiness','acousticness','instrumentalness','liveness','valence','tempo','uri','duration_ms','time_signature']]

# %%
# Hand-pick playlists to get music information from

playlists = {}

# Pop
playlists['todays_top_hits'] = '37i9dQZF1DXcBWIGoYBM5M'
playlists['mega_hit_mix'] = '37i9dQZF1DXbYM3nMM0oPk'
playlists['pop_up'] = '37i9dQZF1DX6aTaZa0K6VA'
playlists['hit_rewind'] = '37i9dQZF1DX0s5kDXi1oC5'
playlists['soft_pop_hits'] = '37i9dQZF1DWTwnEm1IYyoj'
playlists['party_hits'] = '37i9dQZF1DXa2PvUpywmrr'
playlists['pop_remix'] = '37i9dQZF1DXcZDD7cfEKhW'

# Rock
playlists['rock_classics'] = '37i9dQZF1DWXRqgorJj26U'
playlists['rock_this'] = '37i9dQZF1DXcF6B6QPhFDv'
playlists['70s_rock_anthems'] = '37i9dQZF1DWWwzidNQX6jx'
playlists['80s_rock_anthems'] = '37i9dQZF1DX1spT6G94GFC'
playlists['90s_rock_anthems'] = '37i9dQZF1DX1rVvRgjX59F'
playlists['00s_rock_anthems'] = '37i9dQZF1DX3oM43CtKnRV'
playlists['soft_rock'] = '37i9dQZF1DX6xOPeSOGone'
playlists['legendary'] = '37i9dQZF1DWWGFQLoP9qlv'
playlists['rock_party'] = '37i9dQZF1DX8FwnYE6PRvL'
playlists['80s_hard_rock'] = '37i9dQZF1DX68H8ZujdnN7'

# Dance, Electro, Techno, House
playlists['mint'] = '37i9dQZF1DX4dyzvuaRJ0n'
playlists['dance_party'] = '37i9dQZF1DXaXB8fQg7xif'
playlists['throwback_party'] = '37i9dQZF1DX7F6T2n2fegs'
playlists['massive_dance_hits'] = '37i9dQZF1DX5uokaTN4FTR'
playlists['techno_bunker'] = '37i9dQZF1DX6J5NfMJS675'
playlists['best_of_house_2000_2010'] = '4feq7UBWFnq7ACWqILr3D5'

# Rap
playlists['rap_caviar'] = '37i9dQZF1DX0XUsuxWHRQd'
playlists['get_turnt'] = '37i9dQZF1DWY4xHQp97fN6'
playlists['i_love_my_90s_hiphop'] = '37i9dQZF1DX186v583rmzp'
playlists['most_necessary'] = '37i9dQZF1DX2RxBh64BHjQ'

# R&B
playlists['are_be'] = '37i9dQZF1DX4SBhb3fqCJd'
playlists['i_love_my_00s_rb'] = '37i9dQZF1DWYmmr74INQlb'
playlists['i_love_my_90s_rb'] = '37i9dQZF1DX6VDO8a6cQME'

# Jazz & Blues
playlists['coffee_table_jazz'] = '37i9dQZF1DWVqfgj8NZEp1'
playlists['funky_heavy_bluesy'] = '37i9dQZF1DX9stbPFTxeaB'
playlists['jazz_classics'] = '37i9dQZF1DXbITWG1ZJKYt'
playlists['blues_classics'] = '37i9dQZF1DXd9rSDyQguIk'

# Country
playlists['hot_country'] = '37i9dQZF1DX1lVhptIYRda'
playlists['90s_country'] = '37i9dQZF1DWVpjAJGB70vU'

# Classical
playlists['classical_essentials'] = '37i9dQZF1DWWEJlAGA9gs0'

# Latin
playlists['viva_latino'] = '37i9dQZF1DX10zKzsJ2jva'

# Other
playlists['beast_mode'] = '37i9dQZF1DX76Wlfdnj7AP'

# %%
# Run the crawler for each playlist.. create the final database

# !pip install tqdm
from tqdm import tqdm as tqdm
import time

database = pd.DataFrame([])

for playlist in tqdm(list(playlists.values())):
        playlist_crawler(playlist)
        database = database.append(final)
# Out:
# 100%|██████████| 39/39 [09:58<00:00, 15.34s/it]

# %%
database.reset_index(drop=True, inplace=True)

# %%
database = database[~database.duplicated(['artist', 'title'])]
